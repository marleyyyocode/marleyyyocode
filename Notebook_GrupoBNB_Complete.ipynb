# %% [markdown]
# # 🚀 Pipeline Completo BNB Price Prediction
#
# **Objetivo**: Predicción y proyección de precios de Binance Coin (BNB) usando modelos de Machine Learning y Deep Learning
#
# **Modelos**:
# - Baseline: Regresión Lineal
# - LSTM Univariado (optimizado)
# - CNN Univariado (optimizado)
# - LSTM Multivariado (optimizado)
#
# **Características**:
# - Optimización individual de hiperparámetros por modelo (~60 experimentos)
# - Proyecciones 15 días hacia el futuro
# - Visualizaciones comprehensivas
# - Cross-validation temporal
#
# **Tiempo estimado**: 30-40 minutos

# %% [markdown]
# ## 1. ⚙️ Configuración Inicial
#
# Instalación de dependencias y configuración del entorno.

# %%
# Instalación de dependencias
# !pip install -q yfinance pandas numpy matplotlib seaborn scikit-learn tensorflow joblib

print('✅ Dependencias instaladas correctamente')

# %%
# Importar librerías
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import joblib

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from tensorflow import keras
from tensorflow.keras import layers, regularizers, optimizers
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten

import random
import os
from datetime import datetime, timedelta

# Configurar seeds para reproducibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
import tensorflow as tf
tf.random.set_seed(SEED)

# Configurar matplotlib
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

print('✅ Librerías importadas y seeds configurados (SEED=42)')
